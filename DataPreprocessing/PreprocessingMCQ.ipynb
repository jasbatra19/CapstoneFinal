# %%
import pandas as pd

# %%
df = pd.read_csv("../QuestionGenerator/mcqAnswer/questionAnswer.csv")
df
# Out:
#                                              questions  \
# 0    1. Java Source Code is compiled into _________...
# 1                         2. Enums were introduced in?
# 2         3. Default, public , protected, private are?
# 3    4. Which of the following is used to interpret...
# 4    5. HTML based Java Documentary help can be acc...
# ..                                                 ...
# 183                              16. Why ndim is used?
# 184  17. What will be output for the following code...
# 185  18. What will be output for the following code...
# 186  19. Which of the following indexing capabiliti...
# 187               20. Which of the following is false?
#
#                                                answers
# 0    ['A. .Obj\n    B. Source Code\n    C. Bytecode...
# 1    ['A. Java 4.0\n    B. Java 8.0\n    C. Java 5....
# 2    ["A. Access Modifier\n    B. Non-access Modifi...
# 3    ['A. appletviewer\n    B. appletwatcher\n    C...
# 4    ['A. javahelp\n    B. javamanual\n    C. javad...
# ..                                                 ...
# 183  ['A. Returns the number of elements in the und...
# 184  ['A. 0\nB. 1\nC. 2\nD. 3', 'View Answer\nAns :...
# 185  ['A. 0\nB. 1\nC. 2\nD. 3', 'View Answer\nAns :...
# 186  ['A. In\nB. ix\nC. ipy\nD. iy', 'View Answer\n...
# 187  ['A. The integer format tracks only the locati...
#
# [188 rows x 2 columns]

# %% [markdown]
# ### Preprocessing of questions

# %%
questions=df['questions']
question=[]
for data in questions:
    entry=data.replace("_","")
    entry=entry.strip().split(".")
    question.append(entry[1])
df['question']=question

# %% [markdown]
# ## Preprocessing of options for mcqs

# %%
answers=df['answers']
optionA=[]
optionB=[]
optionC=[]
optionD=[]
answer=[]
explanation=[]
for data in answers:
    entry = data.replace('A.', "   ").replace('B.', "   ").replace('C.', "   ").replace("D.", "   ").replace("View Answer", "   ").replace("\\n", "").replace("'",'').replace("\"",'').replace("Ans : ","   ").replace("Explanation:","   ")
    entry = entry.split(",")
    
    # Further split each element based on spaces
    split_entries = [part.strip() for part in entry[0].split('   ') if part.strip()]
    # print(split_entries)
    while len(split_entries)<5:
        split_entries.append("")
    optionA.append(split_entries[1])
    optionB.append(split_entries[2])
    optionC.append(split_entries[3])
    optionD.append(split_entries[4])

    split_answers=[part.strip() for part in entry[1].split("   ") if part.strip()]
    answer.append(split_answers[0])
    while len(split_answers)<2:
        split_answers.append("")
    explanation.append(split_answers[1])


    

          
    
df['A']=optionA
df['B']=optionB
df['C']=optionC
df['D']=optionD
df['answer']=answer
df['explanation']=explanation



df
# Out:
#                                              questions  \
# 0    1. Java Source Code is compiled into _________...
# 1                         2. Enums were introduced in?
# 2         3. Default, public , protected, private are?
# 3    4. Which of the following is used to interpret...
# 4    5. HTML based Java Documentary help can be acc...
# ..                                                 ...
# 183                              16. Why ndim is used?
# 184  17. What will be output for the following code...
# 185  18. What will be output for the following code...
# 186  19. Which of the following indexing capabiliti...
# 187               20. Which of the following is false?
#
#                                                answers  \
# 0    ['A. .Obj\n    B. Source Code\n    C. Bytecode...
# 1    ['A. Java 4.0\n    B. Java 8.0\n    C. Java 5....
# 2    ["A. Access Modifier\n    B. Non-access Modifi...
# 3    ['A. appletviewer\n    B. appletwatcher\n    C...
# 4    ['A. javahelp\n    B. javamanual\n    C. javad...
# ..                                                 ...
# 183  ['A. Returns the number of elements in the und...
# 184  ['A. 0\nB. 1\nC. 2\nD. 3', 'View Answer\nAns :...
# 185  ['A. 0\nB. 1\nC. 2\nD. 3', 'View Answer\nAns :...
# 186  ['A. In\nB. ix\nC. ipy\nD. iy', 'View Answer\n...
# 187  ['A. The integer format tracks only the locati...
#
#                                               question  \
# 0                   Java Source Code is compiled into
# 1                            Enums were introduced in?
# 2            Default, public , protected, private are?
# 3     Which of the following is used to interpret a...
# 4     HTML based Java Documentary help can be acces...
# ..                                                 ...
# 183                                  Why ndim is used?
# 184   What will be output for the following code?\r...
# 185   What will be output for the following code?\r...
# 186   Which of the following indexing capabilities ...
# 187                   Which of the following is false?
#
#                                                      A  \
# 0                                                 .Obj
# 1                                             Java 4.0
# 2                                      Access Modifier
# 3                                         appletviewer
# 4                                             javahelp
# ..                                                 ...
# 183  Returns the number of elements in the underlyi...
# 184                                                  0
# 185                                                  0
# 186                                                 In
# 187  The integer format tracks only the locations a...
#
#                                                      B  \
# 0                                          Source Code
# 1                                             Java 8.0
# 2                                 Non-access Modifiers
# 3                                        appletwatcher
# 4                                           javamanual
# ..                                                 ...
# 183                     Returns the Series as ndarray.
# 184                                                  1
# 185                                                  1
# 186                                                 ix
# 187  Pandas follow the NumPy convention of raising ...
#
#                                                      C  \
# 0                                             Bytecode
# 1                                             Java 5.0
# 2                                         Both A and B
# 3                                           appletshow
# 4                                              javadoc
# ..                                                 ...
# 183  Returns the number of dimensions of the underl...
# 184                                                  2
# 185                                                  2
# 186                                                ipy
# 187           Two kinds of SparseIndex are implemented
#
#                                                      D            answer  \
# 0                                                 .Exe                 C
# 1                                             Java 6.0                 C
# 2                                         Its variable                 A
# 3                                         appletscreen                 A
# 4                                        None of these                 C
# ..                                                 ...               ...
# 183                                                     by definition 1.
# 184                                                  3                 B
# 185                                                  3                 C
# 186                                                 iy                 B
# 187  The integer format keeps an arrays of all of t...                 A
#
#                                            explanation
# 0         Java Source Code is compiled into Bytecode.]
# 1    Enums were introduced in Java 5.0. Enums restr...
# 2                           Access Modifiers : default
# 3    appletviewer is used to interpret and execute ...
# 4    HTML based Java Documentary help can be access...
# ..                                                 ...
# 183                  Returns a list of the axis labels
# 184  Returns the number of dimensions of the object...
# 185    size : Returns the size(length) of the series.]
# 186               ix and reindex are 100% equivalent.]
# 187  The block format tracks only the locations and...
#
# [188 rows x 9 columns]

# %%
df = df.drop(columns=['questions','answers'])

# %%
df
# Out:
#                                               question  \
# 0                   Java Source Code is compiled into
# 1                            Enums were introduced in?
# 2            Default, public , protected, private are?
# 3     Which of the following is used to interpret a...
# 4     HTML based Java Documentary help can be acces...
# ..                                                 ...
# 183                                  Why ndim is used?
# 184   What will be output for the following code?\r...
# 185   What will be output for the following code?\r...
# 186   Which of the following indexing capabilities ...
# 187                   Which of the following is false?
#
#                                                      A  \
# 0                                                 .Obj
# 1                                             Java 4.0
# 2                                      Access Modifier
# 3                                         appletviewer
# 4                                             javahelp
# ..                                                 ...
# 183  Returns the number of elements in the underlyi...
# 184                                                  0
# 185                                                  0
# 186                                                 In
# 187  The integer format tracks only the locations a...
#
#                                                      B  \
# 0                                          Source Code
# 1                                             Java 8.0
# 2                                 Non-access Modifiers
# 3                                        appletwatcher
# 4                                           javamanual
# ..                                                 ...
# 183                     Returns the Series as ndarray.
# 184                                                  1
# 185                                                  1
# 186                                                 ix
# 187  Pandas follow the NumPy convention of raising ...
#
#                                                      C  \
# 0                                             Bytecode
# 1                                             Java 5.0
# 2                                         Both A and B
# 3                                           appletshow
# 4                                              javadoc
# ..                                                 ...
# 183  Returns the number of dimensions of the underl...
# 184                                                  2
# 185                                                  2
# 186                                                ipy
# 187           Two kinds of SparseIndex are implemented
#
#                                                      D            answer  \
# 0                                                 .Exe                 C
# 1                                             Java 6.0                 C
# 2                                         Its variable                 A
# 3                                         appletscreen                 A
# 4                                        None of these                 C
# ..                                                 ...               ...
# 183                                                     by definition 1.
# 184                                                  3                 B
# 185                                                  3                 C
# 186                                                 iy                 B
# 187  The integer format keeps an arrays of all of t...                 A
#
#                                            explanation
# 0         Java Source Code is compiled into Bytecode.]
# 1    Enums were introduced in Java 5.0. Enums restr...
# 2                           Access Modifiers : default
# 3    appletviewer is used to interpret and execute ...
# 4    HTML based Java Documentary help can be access...
# ..                                                 ...
# 183                  Returns a list of the axis labels
# 184  Returns the number of dimensions of the object...
# 185    size : Returns the size(length) of the series.]
# 186               ix and reindex are 100% equivalent.]
# 187  The block format tracks only the locations and...
#
# [188 rows x 7 columns]

# %%
#  saving this preprocessed data into csv
df.to_csv('../dataset/PreprocessedDataSetMCQ.csv', index=False)
