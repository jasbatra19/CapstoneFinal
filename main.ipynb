# %% [markdown]
# ## Capstone Project..

# %%
# importing libraries and modules
import pandas as pd
import random

# %%
# dataset integration
df=pd.read_csv("dataset/trueFalse.csv")
df
# Out:
#                                              Question  Answer
# 0   Threads within the same process can share data...    True
# 1   A user-level process cannot modify its own pag...    True
# 2   Immediately after a process has been forked, t...   False
# 3   Hyper-threading refers to the situation in whi...   False
# 4   The scheduler is the part of an Operating Syst...   False
# 5   The best way to correct virtual memory thrashi...   False
# 6   Most PC operating systems do not support multi...   False
# 7   Threads in a process share same file descriptors.    True
# 8   In a modern operating system using memory prot...   False
# 9   A Remote Procedure Call (RPC) can be used to c...    True
# 10  The complexity of handling software TLB faults...    True
# 11  DMA is a mechanism for allowing an I/O device ...    True
# 12  Memory mapped I/O determines how the pages of ...   False
# 13  There is only one MBR (master boot record) on ...   False
# 14  A context switch from one process to another c...   False
# 15  Multiple processes can correspond to the same ...    True
# 16  The same process can correspond to multiple pr...   False
# 17  Memory Mapped I/O devices are accessed with sp...   False
# 18       RAID-5 is 5 times more reliable than RAID-1.   False
# 19  One advantage of a software TLB is that the sa...    True
# 20  Compulsory misses in a cache can be reduced wi...    True
# 21  Non-volatile Ram (NVRAM) can improve the durab...    True
# 22  A process in user mode cannot execute certain ...    True
# 23  A context switch can occur only after processi...   False
# 24  Context-switching between threads of the same ...   False
# 25  n advantage of implementing threads in user sp...    True
# 26  Deadlock can never occur if no process is allo...    True
# 27  Two processes reading from the same virtual ad...   False
# 28  With dynamic relocation, hardware dynamically ...    True
# 29  A system that provides segmentation without pa...    True

# %%
# speech engine
import pyttsx3
import speech_recognition as sr


engine=pyttsx3.init('sapi5') #use nsss for mac
voice=engine.getProperty('voices')
engine.setProperty('voice',voice[1].id)
engine.setProperty('volume',1.0)
engine.setProperty('rate',150)

def speak(audio):
    engine.say(audio)
    engine.runAndWait()
    
def record_answer():
    r=sr.Recognizer()
    with sr.Microphone() as source:
        r.pause_threshold=1
        audio=r.listen(source)

    try:
            print("listening")
            ans=r.recognize_google(audio,language='en-in')
            print(ans)
    except Exception as e:
            return "None"
    return ans

# %%
if __name__=="__main__":
    # speak("welcome to the test environment")
    noOfQues=df.shape[0]
    print(noOfQues)
    quesBank=random.sample(range(noOfQues),2)
    print(quesBank)
    for i in quesBank:
        speak(df.iloc[i][0])
        actualAns=df.iloc[i][1]
        ans=record_answer()
        if(ans==str(actualAns).lower()):
            speak("correct")
        else:
            speak("incorrect")
# Out:
# 30
# [19, 5]
# listening
# listening
# false
